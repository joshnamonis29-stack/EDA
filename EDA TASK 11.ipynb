# %%
import pandas as pd

# %%
df=pd.read_csv("Automobile_data (2).csv")

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=df.replace('?',np.nan)
print(df.head())
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
cols=["horsepower","peak-rpm","price","stroke","bore"]
for col in cols:
    df[col]=pd.to_numeric(df[col],errors="coerce")
print(df[cols].dtypes)
# Out:
# horsepower    float64
# peak-rpm      float64
# price         float64
# stroke        float64
# bore          float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df["horsepower"]=df["horsepower"].fillna(df["horsepower"].median())

# %%
df["horsepower"]
# Out:
# 0      111.0
# 1      111.0
# 2      154.0
# 3      102.0
# 4      115.0
#        ...
# 200    114.0
# 201    160.0
# 202    134.0
# 203    106.0
# 204    114.0
# Name: horsepower, Length: 205, dtype: float64

# %%
df["peak-rpm"]=df["peak-rpm"].fillna(df["peak-rpm"].median())

# %%
df["peak-rpm"]
# Out:
# 0      5000.0
# 1      5000.0
# 2      5000.0
# 3      5500.0
# 4      5500.0
#         ...
# 200    5400.0
# 201    5300.0
# 202    5500.0
# 203    4800.0
# 204    5400.0
# Name: peak-rpm, Length: 205, dtype: float64

# %%
df["price"]=df["price"].fillna(df["price"].median())

# %%
df["price"]
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 205, dtype: float64

# %%
df["stroke"]=df["stroke"].fillna(df["stroke"].median())

# %%
df["stroke"]
# Out:
# 0      2.68
# 1      2.68
# 2      3.47
# 3      3.40
# 4      3.40
#        ...
# 200    3.15
# 201    3.15
# 202    2.87
# 203    3.40
# 204    3.15
# Name: stroke, Length: 205, dtype: float64

# %%
df["bore"]=df["bore"].fillna(df["bore"].median())

# %%
df["bore"]
# Out:
# 0      3.47
# 1      3.47
# 2      2.68
# 3      3.19
# 4      3.19
#        ...
# 200    3.78
# 201    3.78
# 202    3.58
# 203    3.01
# 204    3.78
# Name: bore, Length: 205, dtype: float64

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  0
# stroke                0
# compression-ratio     0
# horsepower            0
# peak-rpm              0
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
df["power_to_weight_ratio"]=df["horsepower"]/df["curb-weight"] 

print(df[["horsepower","curb-weight","power_to_weight_ratio"]].head())
# Out:
#    horsepower  curb-weight  power_to_weight_ratio
# 0       111.0         2548               0.043564
# 1       111.0         2548               0.043564
# 2       154.0         2823               0.054552
# 3       102.0         2337               0.043646
# 4       115.0         2824               0.040722

# %%
df["combined_mpg"] = (df["city-mpg"] + df["highway-mpg"]) / 2

print(df[["city-mpg","highway-mpg","combined_mpg"]].head())
# Out:
#    city-mpg  highway-mpg  combined_mpg
# 0        21           27          24.0
# 1        21           27          24.0
# 2        19           26          22.5
# 3        24           30          27.0
# 4        18           22          20.0

# %%
body_style_summary = df.groupby('body-style')[
    ['price', 'horsepower', 'curb-weight', 'combined_mpg', 'power_to_weight_ratio']
].agg(['count', 'mean', 'median', 'max'])

print(body_style_summary)
# Out:
#             price                                 horsepower              \
#             count          mean   median      max      count        mean
# body-style
# convertible     6  21890.500000  17084.5  37028.0          6  131.666667
# hardtop         8  22208.500000  19687.5  45400.0          8  142.250000
# hatchback      70   9967.085714   8897.0  22018.0         70  101.242857
# sedan          96  14372.989583  10846.5  41315.0         96  103.104167
# wagon          25  12371.960000  11694.0  28248.0         25   97.640000
#
#                           curb-weight                            combined_mpg  \
#             median    max       count         mean  median   max        count
# body-style
# convertible  113.5  207.0           6  2801.666667  2674.0  3685            6
# hardtop      119.5  207.0           8  2810.625000  2717.5  3715            8
# hatchback     89.0  288.0          70  2348.185714  2294.5  3366           70
# ...

# %%
body_style_summary = df.groupby('engine-location')[
    ['price', 'horsepower', 'curb-weight', 'combined_mpg', 'power_to_weight_ratio']
].agg(['count', 'mean', 'median', 'max'])

print(body_style_summary)
# Out:
#                 price                                 horsepower              \
#                 count          mean   median      max      count        mean
# engine-location
# front             202  12832.816832  10295.0  45400.0        202  102.638614
# rear                3  34528.000000  34028.0  37028.0          3  207.000000
#
#                               curb-weight                             \
#                 median    max       count         mean  median   max
# engine-location
# front             95.0  288.0         202  2552.371287  2412.0  4066
# rear             207.0  207.0           3  2770.666667  2756.0  2800
#
#                 combined_mpg                         power_to_weight_ratio  \
#                        count       mean median   max                 count
# engine-location
# front                    202  28.089109   27.0  51.5                   202
# rear                       3  21.000000   21.0  21.0                     3
#
#
# ...
